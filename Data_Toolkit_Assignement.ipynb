# %%
# Read the all answers of given questions

# %%
#Q1) Demonstrate three different methods for creating identical 2D arrays in NumPy Provide the code for each method and the final output after each method.
# Here are three different methods to create identical 2D arrays using NumPy:

### Method 1: Using `np.array()`
import numpy as np

# Method 1: Using np.array()
array_1 = np.array([[1, 2, 3], [4, 5, 6]])
print("Method 1: \n", array_1)

# Method 2: Using np.zeros() and setting values
array_2 = np.zeros((2, 3), dtype=int)
array_2[0] = [1, 2, 3]
array_2[1] = [4, 5, 6]
print("\nMethod 2: \n", array_2)

# Method 3: Using np.full()
array_3 = np.full((2, 3), [[1, 2, 3], [4, 5, 6]], dtype=int)
print("\nMethod 3: \n", array_3)
# Out:
# Method 1:
#  [[1 2 3]
#  [4 5 6]]
#
# Method 2:
#  [[1 2 3]
#  [4 5 6]]
#
# Method 3:
#  [[1 2 3]
#  [4 5 6]]

# %%
# Q2) Using the Numpy function, generate an array of wRR evenly spaced numPers Petween w and wR and Reshape that wD array into a 2D array.
import numpy as np

# Generate 100 evenly spaced numbers between 1 and 10
array_1d = np.linspace(1, 10, 100)

# Reshape the 1D array into a 2D array (10 rows and 10 columns)
array_2d = array_1d.reshape(10, 10)

# Output the result
print("2D Array:\n", array_2d)
# Out:
# 2D Array:
#  [[ 1.          1.09090909  1.18181818  1.27272727  1.36363636  1.45454545
#    1.54545455  1.63636364  1.72727273  1.81818182]
#  [ 1.90909091  2.          2.09090909  2.18181818  2.27272727  2.36363636
#    2.45454545  2.54545455  2.63636364  2.72727273]
#  [ 2.81818182  2.90909091  3.          3.09090909  3.18181818  3.27272727
#    3.36363636  3.45454545  3.54545455  3.63636364]
#  [ 3.72727273  3.81818182  3.90909091  4.          4.09090909  4.18181818
#    4.27272727  4.36363636  4.45454545  4.54545455]
#  [ 4.63636364  4.72727273  4.81818182  4.90909091  5.          5.09090909
#    5.18181818  5.27272727  5.36363636  5.45454545]
#  [ 5.54545455  5.63636364  5.72727273  5.81818182  5.90909091  6.
#    6.09090909  6.18181818  6.27272727  6.36363636]
#  [ 6.45454545  6.54545455  6.63636364  6.72727273  6.81818182  6.90909091
#    7.          7.09090909  7.18181818  7.27272727]
#  [ 7.36363636  7.45454545  7.54545455  7.63636364  7.72727273  7.81818182
# ...

# %%
# Q3) Explain the following terms
# The difference in npYarray, npYasarray and npYasanyarrayX
# The difference between Deep copy and shallow copy

#### 1. **The difference between `np.array`, `np.asarray`, and `np.asanyarray`:**

# **`np.array()`**: This function creates a new NumPy array from an existing array or other data structures (like lists). By default, it makes a copy of the input data, but you can change this behavior using the `copy` parameter.

# Example:
import numpy as np
lst = [1, 2, 3]
arr = np.array(lst)
print(arr)


# np.asarray(): It converts the input into an array, but if the input is already an array, it won't create a new copy (it will return the existing array). This makes it more efficient when you don't need to modify the original
# data.

# Example:
arr = np.asarray(lst)  # Won't make a copy if lst is already a NumPy array

# **`np.asanyarray()`**: Similar to `np.asarray()`, but it tries to convert the input into a base class (like `ndarray`), except if the input is already a subclass of `ndarray`. For example, if the input is a matrix
# (a subclass of `ndarray`), `np.asanyarray()` will preserve that type, whereas `np.asarray()` would force it to be a basic `ndarray`.

# Example:
m= np.mat([[1, 2], [3, 4]])
arr = np.asanyarray(m)


#### 2. **The difference between deep copy and shallow copy:**

# Shallow Copy: A shallow copy creates a new object but does not create copies of nested objects inside the original object. Instead, it only copies references to them. This means modifications to the nested objects in the copied array will also affect the original array.

# Example:
import copy
lst = [[1, 2], [3, 4]]
shallow_copy = copy.copy(lst)
shallow_copy[0][0] = 100
print(lst)

# Deep Copy: A deep copy creates a new object and recursively copies all objects inside the original one. This means that changes made to the copied object do not affect the original object.

# Example:
deep_copy = copy.deepcopy(lst)
deep_copy[0][0] = 100
print(lst)
# Out:
# [1 2 3]
# [[100, 2], [3, 4]]
# [[100, 2], [3, 4]]

# %%
# Q4) Generate a 3x3 array with random floating-point numbers between 5 and 20. Then, round each number in the array to 2 decimal places.
import numpy as np

# Generate a 3x3 array with random floating-point numbers between 5 and 20
random_array = np.random.uniform(5, 20, (3, 3))

# Round each number in the array to 2 decimal places
rounded_array = np.round(random_array, 2)

# Output the result
print("Random 3x3 Array:\n", random_array)
print("\nRounded 3x3 Array:\n", rounded_array)
# Out:
# Random 3x3 Array:
#  [[ 7.31154264 18.29528893  8.34535988]
#  [12.91381929  9.2467261  11.6295869 ]
#  [10.23258747 19.56839488 19.07775025]]
#
# Rounded 3x3 Array:
#  [[ 7.31 18.3   8.35]
#  [12.91  9.25 11.63]
#  [10.23 19.57 19.08]]

# %%
# Q5) Create a NumPy array with random integers between 1 and 10 of shape (5, 6). After creating the array, perform the following operations:
# Extract all even integers from the array.
# Extract all odd integers from the array.
import numpy as np

# Create a NumPy array with random integers between 1 and 10 of shape (5, 6)
array = np.random.randint(1, 11, (5, 6))

# Extract all even integers from the array
even_integers = array[array % 2 == 0]

# Extract all odd integers from the array
odd_integers = array[array % 2 != 0]

# Output the original array, even integers, and odd integers
print("Original Array:\n", array)
print("\nEven Integers:\n", even_integers)
print("\nOdd Integers:\n", odd_integers)
# Out:
# Original Array:
#  [[ 3  6  4  8  5  1]
#  [10  2  2  5  7  4]
#  [ 4 10  6  1  1  3]
#  [ 7 10  8  9  1  7]
#  [ 1  6  2  9  1  1]]
#
# Even Integers:
#  [ 6  4  8 10  2  2  4  4 10  6 10  8  6  2]
#
# Odd Integers:
#  [3 5 1 5 7 1 1 3 7 9 1 7 1 9 1 1]

# %%
# Q6) Create a 3D NumPy array of shape (3, 3, 3) containing random integers between 1 and 10. Perform the following operations:
# Find the indices of the maximum values along each depth level (third axis).
# Perform element-wise multiplication of two arrays.
import numpy as np

# Create a 3D array with random integers between 1 and 10, shape (3, 3, 3)
array_3d = np.random.randint(1, 11, (3, 3, 3))

# Find the indices of the maximum values along each depth level (axis=2)
max_indices = np.argmax(array_3d, axis=2)

# Create another 3D array of the same shape for element-wise multiplication
array_3d_2 = np.random.randint(1, 11, (3, 3, 3))

# Perform element-wise multiplication between the two arrays
elementwise_multiplication = np.multiply(array_3d, array_3d_2)

# Output the results
print("Original 3D Array:\n", array_3d)
print("\nIndices of Maximum Values along depth (axis=2):\n", max_indices)
print("\nSecond 3D Array:\n", array_3d_2)
print("\nElement-wise Multiplication of Two Arrays:\n", elementwise_multiplication)
# Out:
# Original 3D Array:
#  [[[ 5  5  9]
#   [ 4  7  5]
#   [ 4  2  2]]
#
#  [[ 1  5  1]
#   [ 2  3  2]
#   [ 9  4 10]]
#
#  [[10 10  2]
#   [ 4 10  5]
#   [ 3  4  6]]]
#
# Indices of Maximum Values along depth (axis=2):
#  [[2 1 0]
#  [1 1 2]
#  [0 1 2]]
#
# Second 3D Array:
#  [[[ 5  6  6]
#   [10  3  3]
#   [ 7  2  2]]
#
#  [[ 9  6  9]
#   [ 3  7  5]
#   [ 6  5  6]]
#
#  [[ 8  9  6]
#   [ 1  1  8]
#   [10  3  7]]]
#
# Element-wise Multiplication of Two Arrays:
#  [[[25 30 54]
#   [40 21 15]
#   [28  4  4]]
#
#  [[ 9 30  9]
#   [ 6 21 10]
#   [54 20 60]]
#
#  [[80 90 12]
#   [ 4 10 40]
#   [30 12 42]]]

# %%
# Q7) Clean and transform the 'Phone' column in the sample dataset to remove non-numeric characters and convert it to a numeric data type. Also, display the table attributes and data types of each column.
import pandas as pd

# Sample dataset with 'Phone' column (replace this with actual dataset loading)
data = {
    'Name': ['John Doe', 'Jane Smith', 'Alice Johnson'],
    'Phone': ['+1-800-555-1234', '(123) 456-7890', '987.654.3210'],
    'Email': ['john@example.com', 'jane@example.com', 'alice@example.com']
}

# Create a DataFrame
df = pd.DataFrame(data)

# Clean and transform 'Phone' column: Remove non-numeric characters
df['Phone'] = df['Phone'].str.replace(r'\D', '', regex=True)

# Convert 'Phone' column to numeric data type
df['Phone'] = pd.to_numeric(df['Phone'])

# Display table attributes and data types
print("DataFrame with cleaned 'Phone' column:\n", df)
print("\nData types of each column:\n", df.dtypes)
# Out:
# DataFrame with cleaned 'Phone' column:
#              Name        Phone              Email
# 0       John Doe  18005551234   john@example.com
# 1     Jane Smith   1234567890   jane@example.com
# 2  Alice Johnson   9876543210  alice@example.com
#
# Data types of each column:
#  Name     object
# Phone     int64
# Email    object
# dtype: object

# %%
# Q8) Perform the following tasks using the People Dataset:
# Read the 'data.csv' file using pandas, skipping the first 50 rows.
# Only read the columns: 'Last Name', 'Gender', 'Email', 'Phone', and 'Salary' from the file.
# Display the first 10 rows of the filtered dataset.
# Extract the 'Salary' column as a Series and display its last 5 values.

import pandas as pd

df=pd.read_csv('/content/sample_data/People Data.csv')
df
filtered_data=df[['Last Name','Gender','Email','Phone','Salary']]
print("First 10 rows of the filtered dataset:\n", filtered_data.head(10))
salary_series = filtered_data['Salary']
print("\nLast 5 values of the 'Salary' column:\n", salary_series.tail(5))
# Out:
# First 10 rows of the filtered dataset:
#    Last Name  Gender                          Email               Phone  Salary
# 0   Mahoney    Male            pwarner@example.org        857.139.8239   90000
# 1    Rivers  Female  fergusonkatherine@example.net                 NaN   80000
# 2    Lowery  Female            fhoward@example.org       (599)782-0605   50000
# 3    Hooper    Male          zjohnston@example.com                 NaN   65000
# 4      Rice  Female               elin@example.net  (390)417-1635x3010  100000
# 5  Caldwell    Male          kaitlin13@example.net          8537800927   50000
# 6   Hoffman    Male         jeffharvey@example.com   093.655.7480x7895   60000
# 7  Andersen    Male           alicia33@example.org          4709522945   65000
# 8      Mays    Male             jake50@example.com        013.820.4758   50000
# 9  Mitchell    Male      lanechristina@example.net  (560)903-5068x4985   50000
#
# Last 5 values of the 'Salary' column:
#  995     90000
# ...

# %%
# Q9) Filter and select rows from the People Dataset, where the:
# "Last Name" column contains the name 'Duke'
# "Gender" column contains the word 'Female'
# 'Salary' should be less than 85,000

import pandas as pd

# Load the dataset (Replace 'data.csv' with the actual path to your CSV file)
df = pd.read_csv('/content/sample_data/People Data.csv')

# Filter rows where "Last Name" contains 'Duke', "Gender" is 'Female', and "Salary" is less than 85,000
filtered_df = df[(df['Last Name'].str.contains('Duke', case=False)) &
                 (df['Gender'] == 'Female') &
                 (df['Salary'] < 85000)]

# Display the filtered rows
print("Filtered DataFrame:\n", filtered_df)
# Out:
# Filtered DataFrame:
#       Index          User Id First Name Last Name  Gender  \
# 45      46  99A502C175C4EBd     Olivia      Duke  Female
# 210    211  DF17975CC0a0373    Katrina      Duke  Female
# 457    458  dcE1B7DE83c1076      Traci      Duke  Female
# 729    730  c9b482D7aa3e682     Lonnie      Duke  Female
#
#                         Email                   Phone Date of birth  \
# 45        diana26@example.net  001-366-475-8607x04350    13-10-1934
# 210       robin78@example.com            740.434.0212    21-09-1935
# 457  perryhoffman@example.org     +1-903-596-0995x489    11-02-1997
# 729   kevinkramer@example.net            982.692.6257    12-05-2015
#
#            Job Title  Salary
# 45           Dentist   60000
# 210  Producer, radio   50000
# 457        Herbalist   50000
# 729     Nurse, adult   70000

# %%
# Q10) Create a 7x5 DataFrame in Pandas using a series generated from 35 random integers between 1 and 6.
import pandas as pd
import numpy as np

# Generate a Series of 35 random integers between 1 and 6
random_series = pd.Series(np.random.randint(1, 7, 35))

# Reshape the Series into a 7x5 DataFrame
df = pd.DataFrame(random_series.values.reshape(7, 5))

# Display the DataFrame
print("7x5 DataFrame:\n", df)
# Out:
# 7x5 DataFrame:
#     0  1  2  3  4
# 0  6  2  1  4  6
# 1  1  4  5  3  3
# 2  2  5  3  6  6
# 3  5  6  1  2  4
# 4  2  4  3  4  4
# 5  2  3  4  4  1
# 6  4  6  5  1  6

# %%
# Q11) Create two different Series, each of length 50, with the following criteria:
# The first Series should contain random numbers ranging from 10 to 50.
# The second Series should contain random numbers ranging from 100 to 1000.
# Create a DataFrame by joining these Series by column, and change the names of the columns to 'col1' and 'col2'.
import pandas as pd
import numpy as np

# Create the first Series with random numbers ranging from 10 to 50
series1 = pd.Series(np.random.randint(10, 51, 50))

# Create the second Series with random numbers ranging from 100 to 1000
series2 = pd.Series(np.random.randint(100, 1001, 50))

# Create a DataFrame by joining the two Series by column
df = pd.DataFrame({'col1': series1, 'col2': series2})

# Display the DataFrame
print("DataFrame with two Series:\n", df)
# Out:
# DataFrame with two Series:
#      col1  col2
# 0     32   694
# 1     43   407
# 2     19   392
# 3     45   411
# 4     36   113
# 5     18   610
# 6     16   574
# 7     49   813
# 8     49   402
# 9     23   693
# 10    19   832
# 11    11   591
# 12    46   284
# 13    24  1000
# 14    49   527
# 15    38   730
# 16    23   889
# 17    27   677
# 18    22   361
# 19    24   645
# 20    41   527
# 21    32   442
# 22    43   317
# 23    22   374
# 24    28   962
# 25    21   188
# 26    48   573
# 27    32   696
# 28    16   724
# 29    19   392
# 30    26   841
# 31    29   211
# 32    21   448
# 33    46   389
# 34    39   749
# 35    22   562
# 36    27   109
# 37    49   403
# 38    15   687
# 39    21   163
# 40    30   804
# 41    37   382
# 42    26   486
# 43    45   680
# 44    36   841
# 45    23   976
# 46    42   411
# 47    11   103
# 48    42   319
# 49    19   758

# %%
df = pd.read_csv('/content/sample_data/People Data.csv')
df
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    27-01-2014
# 1    fergusonkatherine@example.net                    NaN    26-07-1931
# ...

# %%
# Q12) Perform the following operations using the People Dataset:
# Delete the 'Email', 'Phone', and 'Date of Birth' columns from the dataset.
# Delete the rows containing any missing values.
# Print the final output.
import pandas as pd
df = pd.read_csv('/content/sample_data/People Data.csv')
df
df_cleaned = df.dropna()

# Print the final output
print("Final DataFrame after deleting columns and rows with missing values:\n", df_cleaned)
# Out:
# Final DataFrame after deleting columns and rows with missing values:
#       Index          User Id First Name Last Name  Gender  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# 5        6  aF75e6dDEBC5b66     Sherry  Caldwell    Male
# 6        7  efeb05c7Cc94EA3     Ernest   Hoffman    Male
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                        Email                  Phone Date of birth  \
# 0        pwarner@example.org           857.139.8239    27-01-2014
# 2        fhoward@example.org          (599)782-0605    25-11-2013
# ...

# %%
# Q13) Create two NumPy arrays, x and y, each containing 100 random float values between 0 and 1. Perform the following tasks using Matplotlib and NumPy:
# Create a scatter plot using x and y, setting the color of the points to red and the marker style to 'o'.
# Add a horizontal line at y = 0.5 using a dashed line style and label it as 'y = 0.5'.
# Add a vertical line at x = 0.5 using a dotted line style and label it as 'x = 0.5'.
# Label the x-axis as 'X-axis' and the y-axis as 'Y-axis'.
# Set the title of the plot as 'Advanced Scatter Plot of Random Values'.
# Display a legend for the scatter plot, the horizontal line, and the vertical line.
import numpy as np
import matplotlib.pyplot as plt

# Create two NumPy arrays, x and y, each containing 100 random float values between 0 and 1
x = np.random.rand(100)
y = np.random.rand(100)

# Create a scatter plot using x and y
plt.scatter(x, y, color='red', marker='o', label='Random Points')

# Add a horizontal line at y = 0.5 using a dashed line style
plt.axhline(y=0.5, color='blue', linestyle='--', label='y = 0.5')

# Add a vertical line at x = 0.5 using a dotted line style
plt.axvline(x=0.5, color='green', linestyle=':', label='x = 0.5')

# Label the x-axis and y-axis
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Set the title of the plot
plt.title('Advanced Scatter Plot of Random Values')

# Display the legend
plt.legend()

# Show the plot
plt.show()

# %%
# Q14) Create a time-series dataset in a Pandas DataFrame with columns: 'Date', 'Temperature', 'Humidity' and
# Perform the following tasks using Matplotlib:
# a) Plot the 'Temperature' and 'Humidity' on the same plot with different y-axes (left y-axis for 'Temperature' and
# right y-axis for 'Humidity').
# b) Label the x-axis as 'Date'.
# c) Set the title of the plot as 'Temperature and Humidity Over Time'
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Creating a time-series dataset
dates = pd.date_range(start='2023-01-01', periods=100, freq='D')
temperature = np.random.uniform(low=15, high=35, size=100)
humidity = np.random.uniform(low=40, high=80, size=100)

# Creating a DataFrame
data = {'Date': dates, 'Temperature': temperature, 'Humidity': humidity}
df = pd.DataFrame(data)

# Plotting Temperature and Humidity on the same plot with different y-axes
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plotting Temperature on the left y-axis
ax1.plot(df['Date'], df['Temperature'], 'r-', label='Temperature')
ax1.set_xlabel('Date')
ax1.set_ylabel('Temperature (°C)', color='r')
ax1.tick_params(axis='y', labelcolor='r')

# Creating a second y-axis for Humidity
ax2 = ax1.twinx()
ax2.plot(df['Date'], df['Humidity'], 'b-', label='Humidity')
ax2.set_ylabel('Humidity (%)', color='b')
ax2.tick_params(axis='y', labelcolor='b')

# Setting the title of the plot
plt.title('Temperature and Humidity Over Time')

plt.show()

# %%
# Q15)Create a NumPy array data containing 1000 samples from a normal distribution. Perform the following
# tasks using Matplotlib:
# a) Plot a histogram of the data with 30 bins.

# b) Overlay a line plot representing the normal distribution's probability density function (PDF).

# c) Label the x-axis as 'Value' and the y-axis as 'Frequency/Probability'.

# d) Set the title of the plot as 'Histogram with PDF Overlay
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Step 1: Generate 1000 samples from a normal distribution
data = np.random.normal(loc=0, scale=1, size=1000)

# Step 2: Plot the histogram
plt.hist(data, bins=30, density=True, alpha=0.6, color='g', label='Histogram')

# Step 3: Overlay the normal distribution PDF
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, 0, 1)  # mean=0, std=1
plt.plot(x, p, 'k', linewidth=2, label='PDF')

# Step 4: Label the axes and set the title
plt.xlabel('Value')
plt.ylabel('Frequency/Probability')
plt.title('Histogram with PDF Overlay')

# Show the legend
plt.legend()

# Display the plot
plt.show()

# %%
# Q16)Set the title of the plot as 'Histogram with PDF Overlay'.
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Generating random data
data = np.random.randn(1000)

# Creating the histogram
plt.hist(data, bins=30, density=True, alpha=0.6, color='g')

# Generating the PDF
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, 0, 1)

# Plotting the PDF on the histogram
plt.plot(x, p, 'k', linewidth=2)

# Setting the title
plt.title('Histogram with PDF Overlay')

# Showing the plot
plt.show()

# %%
# Q17) Create a Seaborn scatter plot of two random arrays, color points based on their position relative to the origin (quadrants), add a legend, label the axes, and set the title as
# 'Quadrant-wise Scatter Plot
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Generate two random arrays
np.random.seed(42)
x = np.random.randn(100)
y = np.random.randn(100)

# Determine the quadrant of each point
def get_quadrant(x, y):
    if x > 0 and y > 0:
        return 'Quadrant I'
    elif x < 0 and y > 0:
        return 'Quadrant II'
    elif x < 0 and y < 0:
        return 'Quadrant III'
    else:
        return 'Quadrant IV'

# Apply the function to categorize points
quadrants = [get_quadrant(xi, yi) for xi, yi in zip(x, y)]

# Create the scatter plot with Seaborn
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y, hue=quadrants, palette='bright', s=100)

# Add axis labels
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

# Add title
plt.title('Quadrant-wise Scatter Plot')

# Add legend
plt.legend(title='Quadrants')

# Show plot
plt.show()

# %%
# Q18)With Bokeh, plot a line chart of a sine wave function, add grid lines, label the axes, and set the title as 'Sine Wave Function'.
# Step 1: Import necessary libraries
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
import numpy as np

# Enable Bokeh output in Jupyter Notebook (skip this if running in a script)
output_notebook()

# Step 2: Generate data for the sine wave
x = np.linspace(0, 10, 500)  # X-axis values from 0 to 10
y = np.sin(x)  # Sine of the x values

# Step 3: Create a Bokeh figure
p = figure(title="Sine Wave Function", x_axis_label='X-axis', y_axis_label='Y-axis')

# Step 4: Plot the sine wave
p.line(x, y, legend_label="Sine Wave", line_width=2)

# Step 5: Customize the grid lines (optional as grid lines are added by default)
p.grid.grid_line_alpha = 0.6  # Adjust the transparency of grid lines

# Display the plot
show(p)
# Out:
#   <div id="d8dafe79-13ec-4e23-a583-9a2cc4838536" data-root-id="p1001" style="display: contents;"></div>

# %%
# Q19)Using Bokeh, generate a bar chart of randomly generated categorical data, color bars based on their values, add hover tooltips to display exact values, label the axes, and set the title
# as 'Random Categorical Bar Chart'.
# Step 1: Import necessary libraries
# Step 1: Import necessary libraries
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.transform import factor_cmap
from bokeh.palettes import Viridis256
import random

# Enable Bokeh output in Jupyter Notebook (skip this if running in a script)
output_notebook()

# Step 2: Generate random categorical data and values
categories = ['Category A', 'Category B', 'Category C', 'Category D', 'Category E']
values = [random.randint(10, 100) for _ in categories]  # Random values for each category

# Create a ColumnDataSource for the data
source = ColumnDataSource(data=dict(categories=categories, values=values))

# Step 3: Create a Bokeh figure
p = figure(x_range=categories, title="Random Categorical Bar Chart",
           x_axis_label='Categories', y_axis_label='Values', toolbar_location=None, tools="")

# Step 4: Create the bar chart with color mapping based on values
p.vbar(x='categories', top='values', width=0.9, source=source,
       fill_color=factor_cmap('categories', palette=Viridis256, factors=categories), legend_field="categories")

# Step 5: Add hover tooltips to display the exact values
hover = HoverTool()
hover.tooltips = [("Category", "@categories"), ("Value", "@values")]
p.add_tools(hover)

# Customize the appearance of the plot
p.legend.orientation = "horizontal"
p.legend.location = "top_center"
p.xgrid.grid_line_color = None  # Remove the vertical grid lines
p.y_range.start = 0  # Start the y-axis at 0

# Display the plot
show(p)
# Out:
#   <div id="b0ab84e3-5a7e-40bf-835f-143f012cb51f" data-root-id="p1070" style="display: contents;"></div>

# %%
# Q20) Using Plotly, create a basic line plot of a randomly generated dataset, label the axes, and set the title as 'Simple Line Plot'.
# Step 1: Import necessary libraries
import plotly.graph_objects as go
import numpy as np

# Step 2: Generate random data for the line plot
x = np.linspace(0, 10, 100)  # X-axis values from 0 to 10
y = np.random.uniform(0, 10, 100)  # Random Y-axis values

# Step 3: Create the line plot
fig = go.Figure(data=go.Scatter(x=x, y=y, mode='lines', name='Random Data'))

# Step 4: Label the axes and set the title
fig.update_layout(
    title='Simple Line Plot',
    xaxis_title='X-axis',
    yaxis_title='Y-axis'
)

# Step 5: Display the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Q21) Using Plotly, create an interactive pie chart of randomly generated data, add labels and percentages, set the title as 'Interactive Pie Chart'.
# Step 1: Import necessary libraries
import plotly.graph_objects as go
import random

# Step 2: Generate random data for the pie chart
labels = ['Category A', 'Category B', 'Category C', 'Category D', 'Category E']
values = [random.randint(10, 100) for _ in labels]

# Step 3: Create the interactive pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=0.3,
                             hoverinfo='label+percent', textinfo='label+percent', textfont_size=15)])

# Step 4: Set the title of the pie chart
fig.update_layout(title_text='Interactive Pie Chart')

# Step 5: Display the pie chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
